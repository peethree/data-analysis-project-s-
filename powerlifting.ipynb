# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
plt.style.use('ggplot')

# %%
pd.set_option('display.max_columns', 200)

# %%
file_path = "C:/Users/....."

df = pd.read_csv(file_path, low_memory=False)

# %%
# Data understanding
df.shape
# Out:
# (3043013, 41)

# %%
df.head(5)
# Out:
#                      Name Sex Event Equipment   Age AgeClass BirthYearClass  \
# 0             Alona Vladi   F   SBD       Raw  33.0    24-34          24-39
# 1      Galina Solovyanova   F   SBD       Raw  43.0    40-44          40-49
# 2          Daniil Voronin   M   SBD       Raw  15.5    16-17          14-18
# 3          Aleksey Krasov   M   SBD       Raw  35.0    35-39          24-39
# 4  Margarita Pleschenkova   M   SBD       Raw  26.5    24-34          24-39
#
#   Division  BodyweightKg WeightClassKg  Squat1Kg  Squat2Kg  Squat3Kg  \
# 0        O         58.30            60      75.0      80.0     -90.0
# 1       M1         73.10            75      95.0     100.0     105.0
# 2        T         67.40            75      85.0      90.0     100.0
# 3        O         66.65            75     125.0     132.0     137.5
# 4        O         72.45            75      80.0      85.0      90.0
#
#    Squat4Kg  Best3SquatKg  Bench1Kg  Bench2Kg  Bench3Kg  Bench4Kg  \
# 0       NaN          80.0      50.0      55.0      60.0       NaN
# 1       NaN         105.0      62.5      67.5     -72.5       NaN
# 2       NaN         100.0      55.0      62.5     -65.0       NaN
# 3       NaN         137.5     115.0     122.5    -127.5       NaN
# 4       NaN          90.0      40.0      50.0     -60.0       NaN
#
#    Best3BenchKg  Deadlift1Kg  Deadlift2Kg  Deadlift3Kg  Deadlift4Kg  \
# 0          60.0         95.0        105.0        107.5          NaN
# 1          67.5        100.0        110.0       -120.0          NaN
# 2          62.5         90.0        100.0        105.0          NaN
# 3         122.5        150.0        165.0        170.0          NaN
# 4          50.0        112.5        120.0        125.0          NaN
#
#    Best3DeadliftKg  TotalKg Place    Dots   Wilks  Glossbrenner  Goodlift  \
# 0            107.5    247.5     1  279.44  282.18        249.42     57.10
# 1            110.0    282.5     1  278.95  272.99        240.35     56.76
# 2            105.0    267.5     1  206.40  206.49        200.45     41.24
# 3            170.0    430.0     1  334.49  334.94        325.32     66.68
# 4            125.0    265.0     1  194.46  193.55        187.29     39.34
#
#   Tested Country State Federation ParentFederation        Date MeetCountry  \
# 0    Yes  Russia   NaN        GFP              NaN  2019-05-11      Russia
# 1    Yes  Russia   NaN        GFP              NaN  2019-05-11      Russia
# 2    Yes  Russia   NaN        GFP              NaN  2019-05-11      Russia
# 3    Yes  Russia   NaN        GFP              NaN  2019-05-11      Russia
# 4    Yes  Russia   NaN        GFP              NaN  2019-05-11      Russia
#
#   MeetState MeetTown         MeetName
# 0       NaN  Bryansk  Open Tournament
# 1       NaN  Bryansk  Open Tournament
# 2       NaN  Bryansk  Open Tournament
# 3       NaN  Bryansk  Open Tournament
# 4       NaN  Bryansk  Open Tournament

# %%
df.columns
# Out:
# Index(['Name', 'Sex', 'Event', 'Equipment', 'Age', 'AgeClass',
#        'BirthYearClass', 'Division', 'BodyweightKg', 'WeightClassKg',
#        'Squat1Kg', 'Squat2Kg', 'Squat3Kg', 'Squat4Kg', 'Best3SquatKg',
#        'Bench1Kg', 'Bench2Kg', 'Bench3Kg', 'Bench4Kg', 'Best3BenchKg',
#        'Deadlift1Kg', 'Deadlift2Kg', 'Deadlift3Kg', 'Deadlift4Kg',
#        'Best3DeadliftKg', 'TotalKg', 'Place', 'Dots', 'Wilks', 'Glossbrenner',
#        'Goodlift', 'Tested', 'Country', 'State', 'Federation',
#        'ParentFederation', 'Date', 'MeetCountry', 'MeetState', 'MeetTown',
#        'MeetName'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Name                 object
# Sex                  object
# Event                object
# Equipment            object
# Age                 float64
# AgeClass             object
# BirthYearClass       object
# Division             object
# BodyweightKg        float64
# WeightClassKg        object
# Squat1Kg            float64
# Squat2Kg            float64
# Squat3Kg            float64
# Squat4Kg            float64
# Best3SquatKg        float64
# Bench1Kg            float64
# Bench2Kg            float64
# Bench3Kg            float64
# Bench4Kg            float64
# Best3BenchKg        float64
# Deadlift1Kg         float64
# Deadlift2Kg         float64
# Deadlift3Kg         float64
# Deadlift4Kg         float64
# Best3DeadliftKg     float64
# TotalKg             float64
# Place                object
# Dots                float64
# Wilks               float64
# Glossbrenner        float64
# Goodlift            float64
# Tested               object
# Country              object
# State                object
# Federation           object
# ParentFederation     object
# Date                 object
# MeetCountry          object
# MeetState            object
# MeetTown             object
# MeetName             object
# dtype: object

# %%
df.describe()
# Out:
#                 Age  BodyweightKg       Squat1Kg       Squat2Kg  \
# count  1.972676e+06  3.004645e+06  905107.000000  895871.000000
# mean   3.076247e+01  8.416742e+01     115.332769      99.527441
# std    1.321350e+01  2.262695e+01     136.395669     160.349024
# min    0.000000e+00  1.000000e+01    -555.000000    -580.000000
# 25%    2.050000e+01  6.720000e+01      90.000000      80.000000
# 50%    2.750000e+01  8.195000e+01     145.000000     145.500000
# 75%    3.850000e+01  9.879000e+01     197.500000     202.500000
# max    9.800000e+01  3.000000e+02     555.000000     577.500000
#
#             Squat3Kg     Squat4Kg  Best3SquatKg      Bench1Kg      Bench2Kg  \
# count  871960.000000  8453.000000  2.033844e+06  1.390103e+06  1.374485e+06
# mean       41.023150    76.853334  1.744520e+02  8.362920e+01  5.756393e+01
# std       190.334257   179.769086  6.837286e+01  9.792505e+01  1.226963e+02
# min      -600.500000  -550.000000 -5.080200e+02 -6.355000e+02 -6.355000e+02
# 25%      -150.000000   -80.000000  1.225000e+02  5.750000e+01 -2.800000e+01
# 50%       117.500000   130.000000  1.700000e+02  1.025000e+02  9.500000e+01
# 75%       192.500000   195.000000  2.177200e+02  1.400000e+02  1.400000e+02
# max       595.000000   592.390000  5.950000e+02  5.510000e+02  5.216300e+02
#
#            Bench3Kg      Bench4Kg  Best3BenchKg   Deadlift1Kg   Deadlift2Kg  \
# count  1.332068e+06  20987.000000  2.684447e+06  1.021109e+06  1.003411e+06
# mean  -1.468420e+01     24.361183  1.181284e+02  1.599149e+02  1.341783e+02
# std    1.385380e+02    159.928474  5.356387e+01  1.073172e+02  1.549512e+02
# min   -5.750000e+02   -515.000000 -5.225000e+02 -5.000000e+02 -5.025000e+02
# 25%   -1.325000e+02   -120.000000  7.500000e+01  1.250000e+02  1.175000e+02
# 50%   -5.750000e+01     75.000000  1.150000e+02  1.800000e+02  1.775000e+02
# 75%    1.175000e+02    150.000000  1.519500e+02  2.225000e+02  2.300000e+02
# max    6.355000e+02    487.610000  6.355000e+02  4.500000e+02  4.675000e+02
#
#          Deadlift3Kg   Deadlift4Kg  Best3DeadliftKg       TotalKg  \
# count  962856.000000  22936.000000     2.206190e+06  2.840592e+06
# mean       23.901474     80.455429     1.901050e+02  3.783307e+02
# std       210.877801    186.097249     6.202838e+01  2.055194e+02
# min      -587.500000   -500.000000    -4.100000e+02  1.000000e+00
# 25%      -200.000000    -77.500000     1.425000e+02  2.018500e+02
# 50%       125.000000    143.000000     1.900000e+02  3.560700e+02
# 75%       206.000000    205.000000     2.350000e+02  5.350000e+02
# max       487.500000    440.500000     4.875000e+02  1.407500e+03
#
#                Dots         Wilks  Glossbrenner      Goodlift
# count  2.815616e+06  2.815616e+06  2.815616e+06  2.566124e+06
# mean   2.754468e+02  2.743523e+02  2.584979e+02  6.455009e+01
# std    1.291727e+02  1.286229e+02  1.222765e+02  1.628555e+01
# min    6.800000e-01  6.700000e-01  6.400000e-01  5.000000e-01
# 25%    1.453000e+02  1.447000e+02  1.368700e+02  5.287000e+01
# 50%    2.982200e+02  2.971700e+02  2.772800e+02  6.446000e+01
# 75%    3.730600e+02  3.713500e+02  3.515700e+02  7.586000e+01
# max    7.991100e+02  7.933300e+02  7.569000e+02  1.761300e+02

# %%
# Dropping columns that I don't plan on using

df = df[['Name', 'Sex', 
         #'Event', 
         'Equipment', 'Age', 'AgeClass',
       'BirthYearClass', 'Division', 'BodyweightKg', 'WeightClassKg',
       #'Squat1Kg', 'Squat2Kg', 'Squat3Kg', 'Squat4Kg', 
         'Best3SquatKg',
       #'Bench1Kg', 'Bench2Kg', 'Bench3Kg', 'Bench4Kg', 
         'Best3BenchKg',
       #'Deadlift1Kg', 'Deadlift2Kg', 'Deadlift3Kg', 'Deadlift4Kg',
       'Best3DeadliftKg', 'TotalKg', 'Place', 'Dots', 'Wilks', 'Glossbrenner',
       'Goodlift', 'Tested', 'Country', #'State', 
         'Federation',
       #'ParentFederation', 
         'Date', 'MeetCountry', #'MeetState', 'MeetTown',
       #'MeetName'
        ]]

# %%
df.head(5)
# Out:
#                      Name Sex Equipment   Age AgeClass BirthYearClass  \
# 0             Alona Vladi   F       Raw  33.0    24-34          24-39
# 1      Galina Solovyanova   F       Raw  43.0    40-44          40-49
# 2          Daniil Voronin   M       Raw  15.5    16-17          14-18
# 3          Aleksey Krasov   M       Raw  35.0    35-39          24-39
# 4  Margarita Pleschenkova   M       Raw  26.5    24-34          24-39
#
#   Division  BodyweightKg WeightClassKg  Best3SquatKg  Best3BenchKg  \
# 0        O         58.30            60          80.0          60.0
# 1       M1         73.10            75         105.0          67.5
# 2        T         67.40            75         100.0          62.5
# 3        O         66.65            75         137.5         122.5
# 4        O         72.45            75          90.0          50.0
#
#    Best3DeadliftKg  TotalKg Place    Dots   Wilks  Glossbrenner  Goodlift  \
# 0            107.5    247.5     1  279.44  282.18        249.42     57.10
# 1            110.0    282.5     1  278.95  272.99        240.35     56.76
# 2            105.0    267.5     1  206.40  206.49        200.45     41.24
# 3            170.0    430.0     1  334.49  334.94        325.32     66.68
# 4            125.0    265.0     1  194.46  193.55        187.29     39.34
#
#   Tested Country Federation        Date MeetCountry
# 0    Yes  Russia        GFP  2019-05-11      Russia
# 1    Yes  Russia        GFP  2019-05-11      Russia
# 2    Yes  Russia        GFP  2019-05-11      Russia
# 3    Yes  Russia        GFP  2019-05-11      Russia
# 4    Yes  Russia        GFP  2019-05-11      Russia

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
# missing values
df.isna().sum()
# Out:
# Name                     0
# Sex                      0
# Equipment                0
# Age                1070337
# AgeClass            814256
# BirthYearClass     1000666
# Division              1435
# BodyweightKg         38368
# WeightClassKg        40757
# Best3SquatKg       1009169
# Best3BenchKg        358566
# Best3DeadliftKg     836823
# TotalKg             202421
# Place                    0
# Dots                227397
# Wilks               227397
# Glossbrenner        227397
# Goodlift            476889
# Tested              804298
# Country            1284501
# Federation               0
# Date                     0
# MeetCountry              0
# dtype: int64

# %%
df.loc[df.duplicated()]
# Out:
#                             Name Sex  Equipment   Age AgeClass BirthYearClass  \
# 889      Sandro Gonzaga Siqueira   M      Wraps  49.0    45-49            NaN
# 4968             Alexis Carvalho   M        Raw  22.0    20-23          19-23
# 8578              Josh Kachaluba   M        Raw  29.0    24-34          24-39
# 9180           Mieczysłąw Maczka   M  Multi-ply  66.0    65-69          60-69
# 9181           Mieczysłąw Maczka   M  Multi-ply  66.0    65-69          60-69
# ...                          ...  ..        ...   ...      ...            ...
# 2993903        Evgeniy Bogatyrev   M  Unlimited  38.0    35-39          24-39
# 2993964           Mikhail Bobkov   M      Wraps  69.0    65-69         70-999
# 2994184        Valeriy Artemchuk   M      Wraps  41.0    40-44          40-49
# 2995626          Aleksey Rybalko   M  Multi-ply  44.0    40-44          40-49
# 2996389            Elena Rudenko   F        Raw  49.0    45-49          50-59
#
#                          Division  BodyweightKg WeightClassKg  Best3SquatKg  \
# 889                       M 45-49         71.00            75         160.0
# 4968                         Open         81.80          82.5         220.0
# 8578                           MO           NaN           NaN           NaN
# 9180            Pro Masters 65-69         81.80          82.5           NaN
# 9181     Pro Military/Fire/Police         81.80          82.5           NaN
# ...                           ...           ...           ...           ...
# 2993903              Amateur Open         82.20          82.5           NaN
# 2993964     Amateur Masters 65-69         94.30           100         207.5
# 2994184     Amateur Masters 40-44         81.50          82.5           NaN
# 2995626         Pro Masters 40-44        103.65           110           NaN
# 2996389         Pro Masters 45-49         85.80            90           NaN
#
#          Best3BenchKg  Best3DeadliftKg  TotalKg Place    Dots   Wilks  \
# 889              85.0            190.0    435.0     1  323.58  322.50
# 4968            157.5            250.0    627.5     1  427.13  422.53
# 8578              NaN              NaN      NaN    NS     NaN     NaN
# 9180            102.5              NaN    102.5     1   69.77   69.02
# 9181            102.5              NaN    102.5     1   69.77   69.02
# ...               ...              ...      ...   ...     ...     ...
# 2993903           NaN              NaN      NaN    DQ     NaN     NaN
# 2993964           NaN              NaN    207.5     1  131.15  129.51
# 2994184           NaN              NaN      NaN    DQ     NaN     NaN
# 2995626         260.0              NaN    260.0     1  157.63  156.08
# 2996389           NaN              NaN      NaN    DQ     NaN     NaN
#
#          Glossbrenner  Goodlift Tested   Country    Federation       Date  \
# 889            312.34     65.25    NaN       NaN       CONBRAP 2019-07-17
# 4968           406.72     87.51    NaN  Portugal  WPC-Portugal 2018-05-05
# 8578              NaN       NaN    NaN       NaN       GPC-CAN 2023-05-06
# 9180            66.44     36.87    NaN   Germany           WPA 2021-04-14
# 9181            66.44     36.87    NaN   Germany           WPA 2021-04-14
# ...               ...       ...    ...       ...           ...        ...
# 2993903           NaN       NaN    Yes    Russia           NAP 2017-09-28
# 2993964        123.89       NaN    Yes    Russia           NAP 2017-09-28
# 2994184           NaN       NaN    Yes    Russia           NAP 2017-09-28
# 2995626        149.04     81.22    NaN       NaN           NAP 2019-12-14
# 2996389           NaN       NaN    NaN    Russia           NAP 2020-03-21
#
#         MeetCountry
# 889          Brazil
# 4968       Portugal
# 8578         Canada
# 9180         Poland
# 9181         Poland
# ...             ...
# 2993903      Russia
# 2993964      Russia
# 2994184      Russia
# 2995626      Russia
# 2996389      Russia
#
# [4639 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Sex', 'Equipment', 'Age', 'AgeClass', 'BirthYearClass',
#        'Division', 'BodyweightKg', 'WeightClassKg', 'Best3SquatKg',
#        'Best3BenchKg', 'Best3DeadliftKg', 'TotalKg', 'Place', 'Dots', 'Wilks',
#        'Glossbrenner', 'Goodlift', 'Tested', 'Country', 'Federation', 'Date',
#        'MeetCountry'],
#       dtype='object')

# %%
# remove dupes from data
df = df.loc[~df.duplicated(subset=['Name', 'Sex', 'Age', 'TotalKg', 'Glossbrenner', 'Country', 'Date', 'MeetCountry'])] \
    .reset_index(drop=True).copy()

# %%
df.shape
# Out:
# (2888110, 23)

# %%
# histogram of biggest squats in meets
ax = df['Best3SquatKg'].plot(kind='hist',
                          bins=100,
                          title='Best3SquatKg')
ax.set_xlabel('Squat (kg)')
plt.show()

# %%
# histogram of biggest bench presses in meets
ax = df['Best3BenchKg'].plot(kind='hist',
                          bins=100,
                          title='Best3BenchKg')
ax.set_xlabel('Bench (kg)')
plt.show()

# %%
# histogram of biggest deadlifts in meets
ax = df['Best3DeadliftKg'].plot(kind='hist',
                          bins=100,
                          title='Best3DeadliftKg')
ax.set_xlabel('Deadlift (kg)')
plt.show()

# %%
ax = df['Age'].plot(kind='kde',
                          title='Age of participants')
ax.set_xlabel('years of age')
# Out:
# Text(0.5, 0, 'years of age')

# %%
ax = df['MeetCountry'].value_counts() \
    .head(5) \
    .plot(kind='bar', title='Top 5 meet countries')
ax.set_xlabel('Countries')
ax.set_ylabel('Number of participants at meet in this country')
plt.show()

# %%
# contestants with stronger deadlift than squat

# %%
df.plot(kind='scatter',
        x='Age',
        y='TotalKg',                     
        title='Age vs. Total combined weight lifted')
plt.show()

# %%
# glossbrenner is a coefficient (based on his / her bodyweight) that gets multiplied by the athlete's total weight lifted
sns.pairplot(df,
            vars=['Age', 'BodyweightKg','TotalKg','Glossbrenner'],
            hue='Sex')
plt.show()

# %%
male_df = df[(df['Sex']=='M') & (df['Equipment']=='Raw')]

# %%
female_df = df[(df['Sex']=='F') & (df['Equipment']=='Raw')]

# %%
# remove the negative values from the df 
# filtered for ages between 18 and 30

filtered_male_df = male_df[
    (male_df['Age'].between(18,30)) &
    (male_df['BodyweightKg'] >= 0) &
    (male_df['Best3SquatKg'] >= 0) &
    (male_df['Best3BenchKg'] >= 0) &
    (male_df['Best3DeadliftKg'] >= 0)
]

# %%
filtered_female_df = female_df[
    (female_df['Age'].between(18,30)) &
    (female_df['BodyweightKg'] >= 0) &
    (female_df['Best3SquatKg'] >= 0) &
    (female_df['Best3BenchKg'] >= 0) &
    (female_df['Best3DeadliftKg'] >= 0)
]

# %%
# correlation between age, bodyweight and max lifts (without equipment) for men
df_corr_male = filtered_male_df[['Age','BodyweightKg','Best3SquatKg','Best3BenchKg','Best3DeadliftKg']].dropna().corr()
df_corr_male
# Out:
#                       Age  BodyweightKg  Best3SquatKg  Best3BenchKg  \
# Age              1.000000      0.171775      0.193750      0.269463
# BodyweightKg     0.171775      1.000000      0.574843      0.561121
# Best3SquatKg     0.193750      0.574843      1.000000      0.817586
# Best3BenchKg     0.269463      0.561121      0.817586      1.000000
# Best3DeadliftKg  0.212731      0.488577      0.853413      0.754859
#
#                  Best3DeadliftKg
# Age                     0.212731
# BodyweightKg            0.488577
# Best3SquatKg            0.853413
# Best3BenchKg            0.754859
# Best3DeadliftKg         1.000000

# %%
# correlations for women aged 18-30
df_corr_female = filtered_female_df[['Age','BodyweightKg','Best3SquatKg','Best3BenchKg','Best3DeadliftKg']].dropna().corr()
df_corr_female
# Out:
#                       Age  BodyweightKg  Best3SquatKg  Best3BenchKg  \
# Age              1.000000      0.126109      0.120755      0.132135
# BodyweightKg     0.126109      1.000000      0.471422      0.372438
# Best3SquatKg     0.120755      0.471422      1.000000      0.809409
# Best3BenchKg     0.132135      0.372438      0.809409      1.000000
# Best3DeadliftKg  0.161019      0.401243      0.858583      0.771155
#
#                  Best3DeadliftKg
# Age                     0.161019
# BodyweightKg            0.401243
# Best3SquatKg            0.858583
# Best3BenchKg            0.771155
# Best3DeadliftKg         1.000000

# %%
sns.heatmap(df_corr_male, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df_corr_female, annot=True)
# Out:
# <AxesSubplot:>

# %%
filtered_male_df_all_ages = male_df[
    (male_df['Age'] >= 0) &
    (male_df['BodyweightKg'] >= 0) &
    (male_df['Best3SquatKg'] >= 0) &
    (male_df['Best3BenchKg'] >= 0) &
    (male_df['Best3DeadliftKg'] >= 0)
]

# %%
filtered_female_df_all_ages = female_df[
    (female_df['Age'] >= 0) &
    (female_df['BodyweightKg'] >= 0) &
    (female_df['Best3SquatKg'] >= 0) &
    (female_df['Best3BenchKg'] >= 0) &
    (female_df['Best3DeadliftKg'] >= 0)
]

# %%
df_corr_male_all_ages = filtered_male_df_all_ages[['Age','BodyweightKg','Best3SquatKg','Best3BenchKg','Best3DeadliftKg']].dropna().corr()
df_corr_male_all_ages
# Out:
#                       Age  BodyweightKg  Best3SquatKg  Best3BenchKg  \
# Age              1.000000      0.205594      0.029580      0.139095
# BodyweightKg     0.205594      1.000000      0.581871      0.595386
# Best3SquatKg     0.029580      0.581871      1.000000      0.840720
# Best3BenchKg     0.139095      0.595386      0.840720      1.000000
# Best3DeadliftKg  0.050749      0.516384      0.885496      0.797827
#
#                  Best3DeadliftKg
# Age                     0.050749
# BodyweightKg            0.516384
# Best3SquatKg            0.885496
# Best3BenchKg            0.797827
# Best3DeadliftKg         1.000000

# %%
df_corr_female_all_ages = filtered_female_df_all_ages[['Age','BodyweightKg','Best3SquatKg','Best3BenchKg','Best3DeadliftKg']].dropna().corr()
df_corr_female_all_ages
# Out:
#                       Age  BodyweightKg  Best3SquatKg  Best3BenchKg  \
# Age              1.000000      0.149921     -0.054078      0.049166
# BodyweightKg     0.149921      1.000000      0.435021      0.383413
# Best3SquatKg    -0.054078      0.435021      1.000000      0.819292
# Best3BenchKg     0.049166      0.383413      0.819292      1.000000
# Best3DeadliftKg  0.045615      0.399763      0.868092      0.792458
#
#                  Best3DeadliftKg
# Age                     0.045615
# BodyweightKg            0.399763
# Best3SquatKg            0.868092
# Best3BenchKg            0.792458
# Best3DeadliftKg         1.000000

# %%
sns.heatmap(df_corr_male_all_ages, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df_corr_female_all_ages, annot=True)
# Out:
# <AxesSubplot:>

# %%
# calculate the difference in correlation between the matrices for age 18-30 and all ages for men and women

correlation_matrix_1 = df_corr_male  
correlation_matrix_2 = df_corr_male_all_ages 

assert correlation_matrix_1.shape == correlation_matrix_2.shape, "Matrices must have the same shape"

correlation_difference = np.abs(correlation_matrix_1.values - correlation_matrix_2.values)

overall_difference = np.sum(correlation_difference)

print(f"Overall Difference in Correlation: {overall_difference}")
# Out:
# Overall Difference in Correlation: 1.3152478118410862

# %%
correlation_matrix_1 = df_corr_female  
correlation_matrix_2 = df_corr_female_all_ages

assert correlation_matrix_1.shape == correlation_matrix_2.shape, "Matrices must have the same shape"

correlation_difference = np.abs(correlation_matrix_1.values - correlation_matrix_2.values)

overall_difference = np.sum(correlation_difference)

print(f"Overall Difference in Correlation: {overall_difference}")
# Out:
# Overall Difference in Correlation: 0.9731320832179156

# %%
# how many men performed a stronger squat than deadlift at a meet(aged 18-30)?

len(filtered_male_df.query('Best3SquatKg > Best3DeadliftKg'))
# Out:
# 15065

# %%
len(filtered_male_df)
# Out:
# 225426

# %%
# percentage of men performing a heavier squat than deadlift at meets (aged 18-30)
percentage = len(filtered_male_df.query('Best3SquatKg > Best3DeadliftKg')) / len(filtered_male_df) * 100
print(f"Percentage of men with stronger squat than deadlift: {percentage:.2f}%")
# Out:
# Percentage of men with stronger squat than deadlift: 6.68%

# %%
# how many women performed a stronger squat than deadlift at a meet(aged 18-30)?
percentage = len(filtered_female_df.query('Best3SquatKg > Best3DeadliftKg')) / len(filtered_female_df) * 100
print(f"Percentage of women with stronger squat than deadlift: {percentage:.2f}%")
# Out:
# Percentage of women with stronger squat than deadlift: 5.32%

# %%
# filtered_male_df['Name'].count 225426
len(filtered_male_df) 225426
# Out:
# 225426

# %%
# which male athletes have performed the highest total at a meet in this dataset? top 10

filtered_male_df.groupby('Name') \
    .agg({'TotalKg': 'max', 'BodyweightKg': 'first', 'Age': 'first'}) \
    .sort_values(by='TotalKg', ascending=False) \
    .head(10)
# Out:
#                    TotalKg  BodyweightKg   Age
# Name
# Jesus Olivares     1152.50        173.40  23.0
# Ray Williams #1    1105.00        166.70  28.0
# Andrew Hause       1101.00        135.10  26.0
# Luke Nall          1090.00        155.30  28.0
# Josh Morris #1     1077.50        187.97  25.0
# Zac Meyers         1077.50        123.00  27.0
# Thomas Davis #1    1077.50        186.60  28.0
# Larry Williams #1  1075.01        128.64  25.0
# Eric Lilliebridge  1075.00        138.80  24.0
# Kirill Sarychev    1072.50        139.00  21.0

# %%
# which female athletes have performed the highest total at a meet in this dataset? top 10

filtered_female_df.groupby('Name') \
    .agg({'TotalKg': 'max', 'BodyweightKg': 'first', 'Age': 'first'}) \
    .sort_values(by='TotalKg', ascending=False) \
    .head(10)
# Out:
#                      TotalKg  BodyweightKg   Age
# Name
# Alexis Jones #1       721.50        141.60  19.5
# April Mathis          705.34        113.40  22.5
# Chakera Ingram        692.50         84.90  22.0
# Bradina Anae          690.00        188.10  22.0
# Sonita Muluh          688.50         97.60  25.0
# Kiersten Scurlock     677.50         74.90  22.0
# Bonica Brown          675.00        136.71  29.0
# Hunter Henderson #1   670.00         81.50  27.0
# Dina Hakeai           650.00        173.20  27.5
# Emelie Leach          649.00        134.85  23.5

# %%
# how many times has there been a total of at least 1000kg (for men) (age 18-30)?

lifts = filtered_male_df.query('TotalKg >= 1000')['Name'] \
    .count()
print(f"Amount of times the men's lifting total is at least 1000kg: {lifts}")
# Out:
# Amount of times the men's lifting total is at least 1000kg: 96

# %%
# how many times has there been a total of at least 1000kg (for men) (all ages)?
lifts = filtered_male_df_all_ages.query('TotalKg >= 1000')['Name'] \
    .count()
print(f"Amount of times the men's (all ages) lifting total is at least 1000kg: {lifts}")
# Out:
# Amount of times the men's (all ages) lifting total is at least 1000kg: 146

# %%
# times women lifted at least a 625kg total (age 18-30)
lifts = filtered_female_df.query('TotalKg >= 625')['Name'] \
    .count()
print(f"Amount of times the women's lifting total is at least 625kg: {lifts}")
# Out:
# Amount of times the women's lifting total is at least 625kg: 60

# %%
# times women lifted at least a 625kg total (all ages)
lifts = filtered_female_df_all_ages.query('TotalKg >= 625')['Name'] \
    .count()
print(f"Amount of times the women's lifting total is at least 625kg: {lifts}")
# Out:
# Amount of times the women's lifting total is at least 625kg: 93

# %%
# what's the average bodyweight for men that can lift heavier than a 1000kg total (age 18-30) ?
avg_weight = filtered_male_df.query('TotalKg >= 1000')['BodyweightKg'].mean()
print(f"The average weight of a man lifting at least a 1000kg total: {avg_weight:.2f} kg")
# Out:
# The average weight of a man lifting at least a 1000kg total: 146.78 kg

# %%
# what's the average bodyweight for men that can lift heavier than a 1000kg total (all ages) ?
avg_weight = filtered_male_df_all_ages.query('TotalKg >= 1000')['BodyweightKg'].mean()
print(f"The average weight of a man lifting at least a 1000kg total: {avg_weight:.2f} kg")
# Out:
# The average weight of a man lifting at least a 1000kg total: 154.26 kg

# %%
# what's the average bodyweight for women that can lift heavier than a 625kg total (age 18-30)?
avg_weight = filtered_female_df.query('TotalKg >= 625')['BodyweightKg'].mean()
print(f"The average weight of a woman lifting at least a 625kg total: {avg_weight:.2f} kg")
# Out:
# The average weight of a woman lifting at least a 625kg total: 122.77 kg

# %%
# what's the average bodyweight for women that can lift heavier than a 625kg total (all ages)?
avg_weight = filtered_female_df_all_ages.query('TotalKg >= 625')['BodyweightKg'].mean()
print(f"The average weight of a woman lifting at least a 625kg total: {avg_weight:.2f} kg")
# Out:
# The average weight of a woman lifting at least a 625kg total: 119.62 kg

# %%
# what's the average age for men that can lift a 1000kg total (all ages)?
avg_age = filtered_male_df_all_ages.query('TotalKg >= 1000')['Age'].mean()
print(f"the average age for men that can lift a 1000kg total: {avg_age}")
# Out:
# the average age for men that can lift a 1000kg total: 29.198630136986303

# %%
# average age for women able to lift 625kg total (all ages) ?
avg_age = filtered_female_df_all_ages.query('TotalKg >= 625')['Age'].mean()
print(f"the average age for women that can lift a 625kg total: {avg_age}")
# Out:
# the average age for women that can lift a 625kg total: 29.322580645161292

# %%
# oldest age someone's lifted a 1000kg total (men)
old = filtered_male_df_all_ages.query('TotalKg >= 1000')['Age'].max()
print(f"oldest age someone's lifted a 1000kg total: {old} years of age")
# Out:
# oldest age someone's lifted a 1000kg total: 43.0 years of age

# %%
# oldest age someone's lifted a 625kg total (women)
old = filtered_female_df_all_ages.query('TotalKg >= 625')['Age'].max()
print(f"oldest age someone's lifted a 625kg total: {old} years of age")
# Out:
# oldest age someone's lifted a 625kg total: 48.0 years of age

# %%
# frequency of 1000kg+ totals vs. bodyweight (all ages) (men)
ax = filtered_male_df_all_ages.query('TotalKg >= 1000')['BodyweightKg'] \
    .plot(kind='hist', bins=25, title='1000+kg totals vs bodyweight')

# %%
# scatter plot for total vs. bodyweight (all ages) (men)
ax = filtered_male_df_all_ages.query('TotalKg >= 1000') \
    .plot(kind='scatter', x='BodyweightKg', y='TotalKg', title='Scatter Plot of Bodyweight vs TotalKg')

# %%
# scatter plot for total vs. age (men) (all ages)
ax = filtered_male_df_all_ages.query('TotalKg >= 1000') \
    .plot(kind='scatter', x='Age', y='TotalKg', title='Scatter Plot of Total vs. Age')

# %%
# distribution of (HIGHLY) elite lifters 
ax = filtered_male_df_all_ages.query('TotalKg >= 1000') \
    .plot(kind='kde', y='TotalKg', title='Men')
ax2 = filtered_female_df_all_ages.query('TotalKg >= 625') \
    .plot(kind='kde', y='TotalKg', title='Women')
